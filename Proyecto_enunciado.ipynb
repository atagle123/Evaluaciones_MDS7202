# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - \<Primer integrante\> Augusto Tagle Montes
#
# ### Link de repositorio de GitHub: https://github.com/atagle123/Evaluaciones_MDS7202
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
import pandas as pd
import os
import shutil
import datetime
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder,FunctionTransformer, OrdinalEncoder 
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
from scipy.stats import chi2_contingency
# %matplotlib inline

# %%
class Profiler:
    def __init__(self,df):
        """
        Clase que se le entrega un dataframe, y crea una carpeta donde se guardaran distintos analisis de los datos
        """
        self.df=df
        nombre_carpeta="EDA_"+datetime.datetime.now().strftime("%d-%m-%Y")  #nombre carpeta
        ruta_carpeta = os.path.join(os.getcwd(),nombre_carpeta)
        self._ruta_carpeta=ruta_carpeta
        self.__create_folder_route()  # llama a función que crea carpeta
        pass

    def __create_folder_route(self,nombre_carpeta=None):
        """
        Función que crea la carpeta en el directorio, si no hay nombre de carpeta, crea el directorio
        """
        if nombre_carpeta==None:
            ruta_carpeta=self._ruta_carpeta
            nombre_carpeta=ruta_carpeta
        else:
            ruta_carpeta=f"{self._ruta_carpeta}/{nombre_carpeta}"
        
        if not os.path.exists(ruta_carpeta):
            os.mkdir(ruta_carpeta)
            print(f'Se ha creado la carpeta "{nombre_carpeta}" en el directorio actual.')
        else:
            print(f'La carpeta "{nombre_carpeta}" ya existe en el directorio actual.')
        pass
    def __select_variables(self,variables):
        """ 
        Selecciona columnas del dataframe, de una lista de variables.
        """
        try:
            df=self.df[variables]
        except:
            df=self.df
        return(df)
    
    def __drop_duplicated(self,df):
        """ 
        Elimina valores duplicados en dataframe
        """
        return(df.drop_duplicates())

    def __separate_non_atomic(self,df):
        """
        Separa las columnas no átomicas de un dataframe
        """
        columnas_no_atomicas = df.filter(regex='-', axis=1).columns.values # deje solo "-" como separador
        for i in columnas_no_atomicas:
            df[i.split("-")] = df[i].str.split(r"\*|\?|:|\(", expand=True)  #expresion regular r"\*|\?|:|\(" para separar las columnas
            df = df.drop(columns=[i]) 
        df = df.replace('nan', np.nan)  
        df = df.apply(pd.to_numeric, errors='ignore')
        return(df)
    
    def __fillnan(self,df,method="None"): # acepta 3 metodos, se pueden agregar mas.
        """
        Llena los valores Nan de un dataframe con el método seleccionado
        """
        if method=="mode":   # cambiar valores nulos por la moda
            df = df.apply(lambda col: col.fillna(col.mode()[0]), axis=0)
            
        elif method=="None":  # no hacer nada con los valores nulos para las variables categoricas y cambiar por moda en variables numericas
            cat_columns = df.select_dtypes(include=['object']).columns
            df[cat_columns] = df[cat_columns].fillna("None")
            
            num_columns = df.select_dtypes(include=['number']).columns
            df[num_columns] = df[num_columns].apply(lambda col: col.fillna(col.mode()[0]), axis=0)

        else: # eliminar valores nulos
            df=df.dropna()   
        return(df)
    
    def __scale_data(self,df,cat_scaler):
        """
        Escala los valores númericos y categoricos
        """
        numeric_columns = df.select_dtypes(include=['number']).columns
        categorical_columns = df.select_dtypes(include=['object']).columns

        numeric_preprocessing = Pipeline([
            ('log', FunctionTransformer(np.log1p)),  # log 
            ('min-maxscaler', MinMaxScaler())   # min max scaler
        ])

        ct = ColumnTransformer(transformers=[
            ("num", numeric_preprocessing, numeric_columns),
            ("scaler_cat", cat_scaler, categorical_columns )]
        )
        transformed_data = ct.fit_transform(df)
        df=pd.DataFrame(transformed_data, columns=df.columns)
        return(df)
    
    def __optimal_clusters(self,df, max_clusters=10): 
        """
        Función que encuentra el número óptimo de clusters, utilizando el método del codo.
        """
        distortions = [KMeans(n_clusters=i, random_state=0).fit(df).inertia_ for i in range(1, max_clusters + 1)]
        plt.plot(range(1, max_clusters + 1), distortions, marker='o')
        plt.title('Método del Codo')
        plt.xlabel('Número de clusters')
        plt.ylabel('Distorsión')
        plt.grid()
        plt.show()
        n_clusters=int(input())
        return(n_clusters)
    def __make_plot_clusters(self,df,clusters):
        """
        Crea un plot de clusters en 2d utilizando PCA
        """
        pca = PCA(n_components=2, random_state=123)
        pca_2d = pca.fit_transform(df)
        plt.figure(figsize=(8, 6))
        plt.scatter(pca_2d[:, 0], pca_2d[:, 1], c=clusters, cmap='viridis')
        plt.title('PCA Visualization of Clusters')
        plt.xlabel("PC1")
        plt.ylabel("PC2")

        plt.colorbar()
        return(plt)
    def __isolation_forest(self,df):
        """
        A partir de un dataframe busca anomalias con isolation forest, devuelve anomalias.
        """
        columnas_numericas = df.select_dtypes(include=['number'])
        scaler = StandardScaler() 
        scaled_data = scaler.fit_transform(columnas_numericas) #esacala los datos antes del modelo

        model = IsolationForest()  # Entrena un Isolation Forest para detectar anomalías

        model.fit(scaled_data)
        anomaly = model.predict(scaled_data) # Predice anomalías en los datos

        return(anomaly)
    def __v_de_cramer(self,confusion_matrix):
        """ 
        Funcion para calcular coeficiente v de cramer, obtenido de:
            Journal of the Korean Statistical Society 42 (2013): 323-328
        """
        chi2 = chi2_contingency(confusion_matrix)[0]
        n = confusion_matrix.sum().sum()
        phi2 = chi2 / n
        r, k = confusion_matrix.shape
        phi2corr = max(0, phi2 - ((k-1)*(r-1)) / (n-1))
        rcorr = r - ((r-1)**2) / (n-1)
        kcorr = k - ((k-1)**2) / (n-1)
        return np.sqrt(phi2corr / (min((kcorr-1), (rcorr-1))))

    def __cramers_matrix(self,df):
        """
        Genera matriz con coeficientes v de cramer
        """
        n = df.shape[1]
        matrix = np.zeros((n, n))
        for i in range(n-1):
            for j in range(n-1):
                if i == j:
                    matrix[i, j] = 1.0
                else:
                    confusion_matrix = pd.crosstab(df.iloc[:, i], df.iloc[:, j])
                    matrix[i, j] = self.__v_de_cramer(confusion_matrix)
        return matrix

    def summarize(self,variables=None,anomaly_treshold=0,clean=False,method="None"):
        """
        Método que resume la lista de variables entregadas
        """
        if clean:   # elejir si hacer summary de variables limpias o no
            df_variables=self.clean_data(variables=variables,method=method)
        else:
            df_variables=self.__select_variables(variables) #selecciona variables
        df_info=pd.DataFrame({ "non-nulls": len(df_variables)-df_variables.isnull().sum().values, "nulls": df_variables.isnull().sum().values, "type": df_variables.dtypes.values,"unique_values":df_variables.nunique()}) # se calculan algunos datos del dataframae

        columnas_numericas = df_variables.select_dtypes(include=['number'])  # selecciona columnas numericas
        df_numeric=columnas_numericas.describe().T
        df_numeric = df_numeric.assign(Zeros=(columnas_numericas == 0).sum(), Negatives=(columnas_numericas < 0).sum(),Outliers=columnas_numericas.apply(lambda col: ((abs(col-col.mean()) > 3* col.std()).sum())))  # calcula estadisticas de variables numericas

        merged_df = pd.merge(df_info, df_numeric, left_index=True, right_index=True, how='outer')

        anomalies=self.__isolation_forest(df_variables) # usaremos isolation forest para detectar anomalias
        diff_anomalies=np.sum(anomalies)
        if diff_anomalies<anomaly_treshold:  # -1 son anomalias y 1 no son anomalias, si hay mas anomalias que no anomalias, levantara una alerta
            print(f"ALERTA DE ANOMALIAS! Hay {-diff_anomalies} mas anomalias que no anomalias ") ##ver si cambiar esto y revisar que funque
        merged_df.to_csv(f"{self._ruta_carpeta}/summary.txt", sep='\t', index=True)
        pass
    
    def plot_vars(self,variables=None,n=10,clean=False,method="None"): 
        """
        Genera imagenes con gráficos de interes, ditribucion de variables, correlacion de variables, histograma con top N categorias y matriz v de cramer.

        """
        if clean:   # elejir si hacer plot de variables limpias o no
            df_variables=self.clean_data(variables=variables,method=method)
        else:
            df_variables=self.__select_variables(variables) #selecciona variables

        self.__create_folder_route(nombre_carpeta="plots") # crea carpeta plots

        columnas_numericas = df_variables.select_dtypes(include=['number'])
        for columna in columnas_numericas.columns.values:
            ax=sns.displot(df_variables[columna], kde=True, color='blue').set(title=f'Distribución de {columna}')
            plt.savefig(f"{self._ruta_carpeta}/plots/{columna}.pdf",format="pdf",bbox_inches='tight')
            plt.clf()

        correlation_matrix = columnas_numericas.corr()
        ax=sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5).set(title=f'Matriz de correlación')
        plt.savefig(f"{self._ruta_carpeta}/plots/Correlation_matrix.pdf",format="pdf",bbox_inches='tight')
        plt.clf()

        categorical_columns = df_variables.select_dtypes(include=['object'])
        for columna in categorical_columns.columns.values:
            top_categories = df_variables[columna].value_counts().nlargest(n)
            plt.bar(top_categories.index, top_categories.values)
            plt.title(f"Histograma top {n} categorias")  
            plt.xticks(rotation = 45)
            plt.savefig(f"{self._ruta_carpeta}/plots/{columna}.pdf",format="pdf",bbox_inches='tight')
            plt.clf()

        cramer_matrix=self.__cramers_matrix(categorical_columns)
        cramer_df = pd.DataFrame(cramer_matrix, columns=categorical_columns.columns, index=categorical_columns.columns)
        ax=sns.heatmap(cramer_df, annot=True, cmap='coolwarm', linewidths=.5)
        plt.savefig(f"{self._ruta_carpeta}/plots/v_cramer.pdf",format="pdf",bbox_inches='tight')
        plt.clf()
        pass
    def clean_data(self,variables=None,method="None"):
        """
        Método para limpiar los datos 
        """
        self.__create_folder_route(nombre_carpeta="clean_data")

        df_variables=self.__select_variables(variables)

        pipeline = Pipeline([
                        ('drop_duplicated', FunctionTransformer(self.__drop_duplicated)),
                        ('separate_non_atomic', FunctionTransformer(self.__separate_non_atomic)),
                        ('fillna', FunctionTransformer(self.__fillnan,kw_args={'method': method}))
                    ])
        df_clean=pipeline.fit_transform(df_variables)
        df_clean.to_csv(f"{self._ruta_carpeta}/clean_data/data.csv", index=True)
        return(df_clean)
    
    def scale(self,variables=None,cat_scaler=OrdinalEncoder(dtype=np.int64),method="None"):
        """
        Método para escalar las variables categoricas y númericas
        """
        self.__create_folder_route(nombre_carpeta="scale")

        df_clean=self.clean_data(variables=variables,method=method)

        df_scaled=self.__scale_data(df_clean,cat_scaler=cat_scaler)
        df_scaled.to_csv(f"{self._ruta_carpeta}/scale/scaled_features.csv", index=True)
        return(df_scaled)
    
    def make_clusters(self,clustering_algorithm,variables=None,method="None"):
        """
        Método para hacer clusters de variables, llama al método optimal clusters, que encuentra el número óptimo de clusters con el método del codo
        """

        self.__create_folder_route(nombre_carpeta="clusters")
        df_variables=self.__select_variables(variables)

        pipeline = Pipeline([
                ('drop_duplicated', FunctionTransformer(self.__drop_duplicated)),
                ('separate_non_atomic', FunctionTransformer(self.__separate_non_atomic)),
                ('fillna', FunctionTransformer(self.__fillnan,kw_args={'method': method})),
                ('scaler', FunctionTransformer(self.__scale_data,kw_args={'cat_scaler': OrdinalEncoder(dtype=np.int64)}))
            ])

        df_preprocesed = pipeline.fit_transform(df_variables)
        n_clusters=self.__optimal_clusters(df_preprocesed) # comprobar que funcione bien
        print(f"n_clusters:{n_clusters}")
        clustering_algorithm.set_params(n_clusters=n_clusters)  
        clusters=clustering_algorithm.fit(df_preprocesed)
        plt_clusters=self.__make_plot_clusters(df_preprocesed,clusters.labels_)
        df_preprocesed["clusters"]=clusters.labels_ 
        plt_clusters.savefig(f"{self._ruta_carpeta}/clusters/data_clusters.png", format='png')
        plt_clusters.close()
        df_preprocesed.to_csv(f"{self._ruta_carpeta}/clusters/data_clusters.csv", index=True)
        pass
    
    def detect_anomalies(self,anomalies_algorithm=IsolationForest(contamination=0.05),variables=None,method="None"):
        """
        Método para detectar ánomalias en los datos
        """
        self.__create_folder_route(nombre_carpeta="anomalies")
        df_summary=self.__select_variables(variables)

        pipeline = Pipeline([
                ('drop_duplicated', FunctionTransformer(self.__drop_duplicated)),
                ('separate_non_atomic', FunctionTransformer(self.__separate_non_atomic)),
                ('fillna', FunctionTransformer(self.__fillnan,kw_args={'method': method})),
                ('scaler', FunctionTransformer(self.__scale_data,kw_args={'cat_scaler': OrdinalEncoder(dtype=np.int64)}))
            ]) 
        df_preprocesed = pipeline.fit_transform(df_summary)

        columnas_numericas = df_preprocesed.select_dtypes(include=['number'])
        anomalies_algorithm.fit(columnas_numericas)
        anomalies = anomalies_algorithm.predict(columnas_numericas)
        
        plt_clusters=self.__make_plot_clusters(df_preprocesed,anomalies)
        df_preprocesed["anomalies"]=anomalies
        plt_clusters.savefig(f"{self._ruta_carpeta}/anomalies/data_anomalies.png", format='png')
        plt_clusters.close()
        df_preprocesed.to_csv(f"{self._ruta_carpeta}/anomalies/data_anomalies.csv", index=True)
        pass

    def profile(self,variables=None,clean=False,method="None",clustering_algorithm=KMeans(n_clusters=2, random_state=1)):
        """
        Ejecuta todos los metodos anteriores correspondientes al analisis de datos
        """
        self.summarize(variables=variables,clean=clean)
        self.plot_vars(variables=variables,clean=clean,method=method)
        self.clean_data(variables=variables,method=method)
        self.scale(variables,method=method)
        self.make_clusters(clustering_algorithm=clustering_algorithm,variables=variables,method=method)
        self.detect_anomalies(variables=variables,method=method)
        pass

    def clearGarbage(self):
        """
        Funcion para eliminar todos los archivos creados por esta clase.
        """
        for root, dirs, files in os.walk(os.getcwd()):
            for directorio in dirs:
                if directorio.startswith("EDA"):
                    ruta_completa = os.path.join(root, directorio)
                    try:
                        shutil.rmtree(directorio)
                        print(f"{directorio} eliminado correctamente")
                    except Exception as e:
                        print(f"No se pudo eliminar el directorio {ruta_completa}: {e}")

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#
# El problema que se abordará será observar si se puede clusterizar a los deportistas de los juegos olimpicos debido a sus caracteristicas "naturales". Por ejemplo el peso, edad, altura, sexo, entre otros.
# Por lo tanto, en este proyecto la idea será trabajar el dataset de los juegos olimpicos, solo con las variables inherentes de cada deportista, por lo que primero se realizará un analisis exploratorio de los datos para ver con que variables deberemos trabajar para lograr este objetivo, luego, se limpiaran los datos (drop valores duplicados, drop valores nulos y eliminación de outliers), despues, se escalaran los datos (numericos y categoricos) en donde posteriormente se aplicaran métodos de clustering, elijiendo la cantidad óptima de clusters con el método del codo.
#  Finalmente se realizará una detección de anomalías con isolation forest y se observaran los clusters de anomalias y del algoritmo de cluster en baja dimensionalidad (reducción con PCA). Con el fin de buscar si existe alguna posible clusterización de los deportistas.
#
# Los datos que tenemos son: 'ID', 'Name', 'Sex', 'Team', 'NOC', 'Games', 'Year', 'Season','City', 'Sport', 'Event', 'Medal' y 'age-height-weight'.
#
# Por lo tanto para lograr nuestro objetivo deberemos usar las variables correspondientes a la edad (age), altura (height), peso (weight) y sexo ("Sex").
# Que corresponden todas a variables numericas, menos el sexo, que es una variable categórica.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Respecto a las variables númericas (sin columnas no átomicas):
#     ![image.png](attachment:image.png)
#     Podemos observar que no existe una gran correlación entre las variables, sin embargo se puede ver que las variables weight y height estan bastante correlacionadas (0.75), lo cual es de esperarse.
#     Las variables distribuyen de la siguiente manera (datos limpios):
#     ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png)
#     Donde se puede observar que height distribuye similar a una normal, y weight y age distribuyen similar a una log-normal.
#
#
#     - Respecto a los valores nulos, solo existen en el dataframe original, en la  variable medal y hay 231333 valores nulos, pero estos corresponden a las personas que no ganaron medalla, por lo tanto no deben ser considerados como valores nulos. En las variables seleccionadas, no hay valores nulos.
#
#     - Para las variables categóricas tenemos solo una variable, que corresponde al sexo, que distribuye de la siguiente manera (datos limpios):
#     ![image-2.png](attachment:image-2.png)
#     Donde se puede ver que hay aproximadamente el doble de hombres que mujeres, en estos datos.
#
#     - En los datos con los que trabajaremos no hay valores duplicados. Sin embargo en el dataset original si habian valores duplicados. Nuestro dataset final (limpio) tiene 99294 valores.
#     - En los datos, existian anomalias preocupantes, por ejemplo existian valores para la altura, peso y edad que eran negativos o cero. Sin embargo fueron eliminados posteriormente por la detección de anomalias con isolation forest y con la eliminación de outliers, donde se eliminan todos los datos alejados mas de 3 desviaciones estandar de la media.
# 3. Creación de Clusters y Anomalías
#     - Luego de limpiar los datos y escalarlos con logaritmo y luego con min-max scaler, y los datos categoricos transformarlos con un ordinal encoder,se crean los clusters:
#
#     - Primero se utilizá k means para clusterizar, con 2 clusters (elegidos mediante método del codo). Se adjunta la visualización obtenida:
#     ![image-6.png](attachment:image-6.png)
#     Se puede observar que las clases estan bastante bien separadas, esto es probablemente debido a los sexos, ya que el algoritmo k means es altamente sensible a datos categoricos.
#     Por lo que se utilizará el algoritmo pero esta vez solo con las variables: age, height y weight.
#     Se obtiene lo siguiente:
#     ![image-8.png](attachment:image-8.png)
#     Se puede ver un "codo" en k=4 , por lo que se utiliza k means para 4 clusters.
#     ![image-10.png](attachment:image-10.png)
#     Aca se puede observar la visualización de los clusters reducida con PCA, donde se pueden ver claramente 4 clusters bien separables.
#
#     - Ahora podemos visualizar anomalías en estos datos, nuevamente se utilizarán las variables: age, height y weight. Y se utilizá un Isolation Forest con contamination= 0.05.
#     ![image-7.png](attachment:image-7.png)
#
#
#
#
# 4. Análisis de Resultados
#     - Al analizar los resultados, se puede observar que existe una clara separación de los datos y de las anomalias, si bien, fue necesario eliminar una variable de las planteadas (sex), para finalmente quedarnos con age, height y weight. Se lográ observar de igual manera la separación de los clusters, por lo que probablemente estos clusters correspondan a distintos tipos de morfologías de los atletas, asociados con cierta edad.
#     Las anomalías podrían ser datos anormales en el dataset, personas de alta estatura o de baja estatura, personas de edad avanzada o jovenes, por ejemplo.
#     Tambien se debe notar que los clusters estan bastante balanceados, lo que significa que corresponden a 4 clusters bastante comunes.
#
#
# 5. Conclusión
#     - En este proyecto se ha encontrado una separación de 4 clusters efectiva de atletas de los juegos olimpicos, utilizando las variables que corresponden a las caracteristicas de los atletas, en este caso son: age, height y weight.
#     - Tambien se ha encontrado que existen ciertas anomalias en el dataset que debieron ser eliminadas (valores negativos por ejemplo).
#     - Se ha encontrado tambien que el algoritmo k means no funcionaba correctamente al introducir variables categoricas (el sexo de la persona en este caso).
#     - Finalmente, los clusters encontrados pueden corresponder a distintos tipos de atletas, segun su morfología y su edad.

# %% [markdown]
# ### Apendice
# Se adjunta el código ejecutado.
# Correr una celda a la vez para no sobreescribir los resultados.

# %%
df=pd.read_parquet("olimpiadas.parquet")
df_prof=Profiler(df)
df_vars=["Sex",'age-height-weight']
# Out:
# La carpeta "c:\Users\augus\Desktop\Laboratorio de programación cientifica\Proyecto_01\EDA_10-11-2023" ya existe en el directorio actual.

# %% [markdown]
# Obtiene todos, para todas las variables.

# %%
df_prof.profile(clean=True,method="None",clustering_algorithm=KMeans(n_clusters=2, random_state=1))

# %% [markdown]
# Obtiene datos para variables de interes ["Sex",'age-height-weight']

# %%
df_prof.profile(variables=df_vars,clean=True,method="None",clustering_algorithm=KMeans(n_clusters=2, random_state=1))
# Out:
# La carpeta "clean_data" ya existe en el directorio actual.
# C:\Users\augus\AppData\Local\Temp\ipykernel_12796\2992057389.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i.split("-")] = df[i].str.split(r"\*|\?|:|\(", expand=True)  #expresion regular r"\*|\?|:|\(" para separar las columnas
# C:\Users\augus\AppData\Local\Temp\ipykernel_12796\2992057389.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Hacer clusters para variables ['age-height-weight']

# %%
df_prof.make_clusters(clustering_algorithm=KMeans(n_clusters=2, random_state=1),variables=['age-height-weight'],method="None")
# Out:
# La carpeta "clusters" ya existe en el directorio actual.
# C:\Users\augus\AppData\Local\Temp\ipykernel_12796\2992057389.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i.split("-")] = df[i].str.split(r"\*|\?|:|\(", expand=True)  #expresion regular r"\*|\?|:|\(" para separar las columnas
# C:\Users\augus\AppData\Local\Temp\ipykernel_12796\2992057389.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Detectar anomalías para variables ['age-height-weight']

# %%
df_prof.detect_anomalies(variables=['age-height-weight'],method="None")
# Out:
# La carpeta "anomalies" ya existe en el directorio actual.

# %% [markdown]
# Limpiar los archivos generados

# %%
#df_prof.clearGarbage()
